# %% [markdown]
# # Text Classification using Word Embeddings and Dense Neural Network Models
#
# ## Building a Hate Speech Classifier
#
# Understanding the text content and predicting the sentiment of the reviews is a form of supervised machine learning. To be more specific, we will be using classification models for solving this problem. We will be building an automated hate speech text classification system in subsequent sections. The major steps to achieve this are mentioned as follows.
#
# + Prepare train and test datasets (optionally a validation dataset)
# + Pre-process and normalize text documents
# + Feature Engineering
# + Model training
# + Model prediction and evaluation
#
# These are the major steps for building our system. Optionally the last step would be to deploy the model in your server or on the cloud. The following figure shows a detailed workflow for building a standard text classification system with supervised learning (classification) models.
#
# In our scenario, documents indicate the posts \ comments and classes indicate the nature of whether the post was a hate speech incited post or not, which can either be hate or nothate making it a binary classification problem. We will build models using deep learning in the subsequent sections.
#
# __Fill the sections marked with blanks or `<YOUR CODE HERE>`__

# %%
# !nvidia-smi
# Out:
# Mon Nov 22 18:32:51 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.44       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   38C    P8    26W / 149W |      0MiB / 11441MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# !pip install contractions
# !pip install textsearch
# !pip install tqdm
import nltk
nltk.download('punkt')
# Out:
# Collecting contractions
#   Downloading contractions-0.0.58-py2.py3-none-any.whl (8.0 kB)
# Collecting textsearch>=0.0.21
#   Downloading textsearch-0.0.21-py2.py3-none-any.whl (7.5 kB)
# Collecting pyahocorasick
#   Downloading pyahocorasick-1.4.2.tar.gz (321 kB)
#      |████████████████████████████████| 321 kB 5.2 MB/s
# Collecting anyascii
#   Downloading anyascii-0.3.0-py3-none-any.whl (284 kB)
#      |████████████████████████████████| 284 kB 39.1 MB/s
# Building wheels for collected packages: pyahocorasick
#   Building wheel for pyahocorasick (setup.py) ... done
#   Created wheel for pyahocorasick: filename=pyahocorasick-1.4.2-cp37-cp37m-linux_x86_64.whl size=85440 sha256=6748f7c620be7f02f165daaa404fb5581bed134b2cb6ca493172d3662e358733
#   Stored in directory: /root/.cache/pip/wheels/25/19/a6/8f363d9939162782bb8439d886469756271abc01f76fbd790f
# Successfully built pyahocorasick
# Installing collected packages: pyahocorasick, anyascii, textsearch, contractions
# Successfully installed anyascii-0.3.0 contractions-0.0.58 pyahocorasick-1.4.2 textsearch-0.0.21
# Requirement already satisfied: textsearch in /usr/local/lib/python3.7/dist-packages (0.0.21)
# Requirement already satisfied: anyascii in /usr/local/lib/python3.7/dist-packages (from textsearch) (0.3.0)
# Requirement already satisfied: pyahocorasick in /usr/local/lib/python3.7/dist-packages (from textsearch) (1.4.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (4.62.3)
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %% [markdown]
# ## Load Dataset - Hate Speech
#
# Social media unfortunately is rampant with hate speech in the form of posts and comments. This is a practical example of perhaps building an automated hate speech detection system using NLP in the form of text classification.
#
# In this notebook, we will leverage an open sourced collection of hate speech posts and comments.
#
# The dataset is available here: [kaggle](https://www.kaggle.com/usharengaraju/dynamically-generated-hate-speech-dataset) which in turn has been curated from a wider [data source for hate speech](https://hatespeechdata.com/)

# %%
import pandas as pd

df = pd.read_csv('HateDataset.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40623 entries, 0 to 40622
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      40623 non-null  int64
#  1   id              40623 non-null  object
#  2   text            40623 non-null  object
#  3   label           40623 non-null  object
#  4   type            40623 non-null  object
#  5   model_wrong     26097 non-null  object
#  6   db.model_preds  26097 non-null  float64
#  7   status          40623 non-null  object
#  8   round           40623 non-null  object
#  9   split           40623 non-null  object
#  10  annotator       40623 non-null  object
# dtypes: float64(1), int64(1), object(9)
# memory usage: 3.4+ MB

# %% [markdown]
# To keep things simple we will focus on predicting the labels from the text content

# %%
df = df[['text', 'label']]
df.head()
# Out:
#                                                 text label
# 0  It should be legal for a husband to rape his wife  hate
# 1                            dalits are lowlife scum  hate
# 2                                dalits are lowlives  hate
# 3  It was a better world when women dare not ques...  hate
# 4  I don't work this hard so that those immigrant...  hate

# %% [markdown]
# ### Split data into train-test datasets

# %%
from sklearn.model_selection import train_test_split

# %%
train_reviews, test_reviews, train_labels, test_labels = train_test_split(df.text.values,
                                                                          df.label.values,
                                                                          test_size=0.2, random_state=42)

# %%
len(train_reviews), len(test_reviews)
# Out:
# (32498, 8125)

# %% [markdown]
# ## Text Wrangling and Normalization
#
# In this section, we will also normalize our corpus by removing accented characters, newline characters and so on. Lets get started

# %% [markdown]
# ### **Question 1**: **Complete** the following utility functions (2 points)
#
# __Hint:__ Use the knowledge gained from NLP-1 or the classification tutorial to solve this

# %%
import contractions
from bs4 import BeautifulSoup
import numpy as np
import re
from tqdm import tqdm
import unicodedata


def strip_html_tags(text):
    # hint use beautifulsoup to remove html tags
    soup = BeautifulSoup(text, "html.parser")
    [s.extract() for s in soup(['iframe', 'script'])]
    stripped_text = soup.get_text()
    stripped_text = re.sub(r'[\r|\n|\r\n]+', '\n', stripped_text)
    return stripped_text

def remove_accented_chars(text):
    # hint use the normalize function from unicodedata
    text = unicodedata.normalize('NFKD', text).encode('ascii', 'ignore').decode('utf-8', 'ignore')
    return text

def pre_process_corpus(docs):
    norm_docs = []
    for doc in tqdm(docs):
        # strip HTML tags
        doc = strip_html_tags(doc)
        # remove extra newlines
        doc = doc.translate(doc.maketrans("\n\t\r", "   "))
        # lower case
        doc = doc.lower()
        # remove accented characters
        doc = remove_accented_chars(doc)
        # fix contractions
        doc = contractions.fix(doc)
        # remove special characters\whitespaces
        # use regex to keep only letters, numbers and spaces
        doc = re.sub(r'[^a-zA-Z0-9\s]', '', doc, flags=re.I|re.A)
        # use regex to remove extra spaces
        doc = re.sub(' +', ' ', doc)
        # remove trailing and leading spaces
        doc = doc.strip() 

        norm_docs.append(doc)
  
    return norm_docs

# %%
# %%time

norm_train_reviews = pre_process_corpus(train_reviews)
norm_test_reviews = pre_process_corpus(test_reviews)
# Out:
#  13%|█▎        | 4152/32498 [00:00<00:04, 5820.09it/s]/usr/local/lib/python3.7/dist-packages/bs4/__init__.py:273: UserWarning: "b'.'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# 100%|██████████| 32498/32498 [00:05<00:00, 5621.75it/s]
# 100%|██████████| 8125/8125 [00:01<00:00, 5560.85it/s]
# CPU times: user 6.58 s, sys: 680 ms, total: 7.26 s
# Wall time: 7.26 s

# %% [markdown]
# ## Label Encode Class Labels
#
# Our dataset has labels in the form of positive and negative classes. We transform them into consumable form by performing label encoding. Label encoding assigns a unique numerical value to each class. For example:
# ``negative: 0 and positive:1``

# %%
import gensim
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dropout, Activation, Dense
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# ### **Question 2**: **Complete** the following transformations (1 point)

# %%
le = LabelEncoder()
# tokenize train reviews & encode train labels
tokenized_train = [nltk.word_tokenize(text)
                       for text in tqdm(norm_train_reviews)]
y_train = le.fit_transform(train_labels)
# tokenize test reviews & encode test labels
tokenized_test = [nltk.word_tokenize(text)
                       for text in tqdm(norm_test_reviews)]
y_test = le.transform(test_labels)
# Out:
# 100%|██████████| 32498/32498 [00:05<00:00, 6441.59it/s]
# 100%|██████████| 8125/8125 [00:01<00:00, 6569.22it/s]

# %% [markdown]
# ## Feature Engineering based on Word2Vec Embeddings
#
# In the previous notebook we discussed different word embedding techniques like word2vec, glove, fastText, etc. In this section we will leverage ``gensim`` to transform our dataset into word2vec  representation

# %%
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %% [markdown]
# ### **Question 3**: **Get** feature vectors using Word2Vec (2 points)
#
# Build the word2vec model on your tokenized train data

# %%
# %%time
# build word2vec model
w2v_num_features = 300
# use a similar config as the tutorial but use a min_count of 2 and train for 10 iterations
w2v_model = gensim.models.Word2Vec(tokenized_train, size=w2v_num_features, window=150,
                                   min_count=2, workers=4, iter=10)
# Out:
# 2021-11-22 18:35:11,982 : INFO : collecting all words and their counts
# 2021-11-22 18:35:11,984 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2021-11-22 18:35:12,032 : INFO : PROGRESS: at sentence #10000, processed 191882 words, keeping 12443 word types
# 2021-11-22 18:35:12,078 : INFO : PROGRESS: at sentence #20000, processed 381657 words, keeping 16843 word types
# 2021-11-22 18:35:12,131 : INFO : PROGRESS: at sentence #30000, processed 569605 words, keeping 19664 word types
# 2021-11-22 18:35:12,147 : INFO : collected 20219 word types from a corpus of 616684 raw words and 32498 sentences
# 2021-11-22 18:35:12,148 : INFO : Loading a fresh vocabulary
# 2021-11-22 18:35:12,187 : INFO : effective_min_count=2 retains 13577 unique words (67% of original 20219, drops 6642)
# 2021-11-22 18:35:12,188 : INFO : effective_min_count=2 leaves 610042 word corpus (98% of original 616684, drops 6642)
# 2021-11-22 18:35:12,245 : INFO : deleting the raw counts dictionary of 20219 items
# 2021-11-22 18:35:12,252 : INFO : sample=0.001 downsamples 57 most-common words
# 2021-11-22 18:35:12,257 : INFO : downsampling leaves estimated 445055 word corpus (73.0% of prior 610042)
# 2021-11-22 18:35:12,294 : INFO : estimated required memory for 13577 words and 300 dimensions: 39373300 bytes
# 2021-11-22 18:35:12,296 : INFO : resetting layer weights
# 2021-11-22 18:35:15,683 : INFO : training model with 4 workers on 13577 vocabulary and 300 features, using sg=0 hs=0 sample=0.001 negative=5 window=150
# 2021-11-22 18:35:16,741 : INFO : EPOCH 1 - PROGRESS: at 46.83% examples, 199833 words/s, in_qsize 7, out_qsize 0
# 2021-11-22 18:35:17,723 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-11-22 18:35:17,750 : INFO : EPOCH 1 - PROGRESS: at 96.70% examples, 209644 words/s, in_qsize 2, out_qsize 1
# 2021-11-22 18:35:17,752 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-11-22 18:35:17,760 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-11-22 18:35:17,768 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-11-22 18:35:17,770 : INFO : EPOCH - 1 : training on 616684 raw words (445369 effective words) took 2.1s, 214627 effective words/s
# 2021-11-22 18:35:18,787 : INFO : EPOCH 2 - PROGRESS: at 43.49% examples, 194635 words/s, in_qsize 7, out_qsize 0
# 2021-11-22 18:35:19,808 : INFO : EPOCH 2 - PROGRESS: at 93.86% examples, 206785 words/s, in_qsize 3, out_qsize 2
# 2021-11-22 18:35:19,811 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-11-22 18:35:19,871 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-11-22 18:35:19,885 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-11-22 18:35:19,895 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-11-22 18:35:19,896 : INFO : EPOCH - 2 : training on 616684 raw words (445151 effective words) took 2.1s, 210943 effective words/s
# 2021-11-22 18:35:20,950 : INFO : EPOCH 3 - PROGRESS: at 46.83% examples, 200916 words/s, in_qsize 7, out_qsize 0
# 2021-11-22 18:35:21,913 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-11-22 18:35:21,947 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-11-22 18:35:21,955 : INFO : EPOCH 3 - PROGRESS: at 98.67% examples, 214826 words/s, in_qsize 1, out_qsize 1
# 2021-11-22 18:35:21,956 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-11-22 18:35:21,973 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-11-22 18:35:21,974 : INFO : EPOCH - 3 : training on 616684 raw words (445074 effective words) took 2.1s, 215444 effective words/s
# 2021-11-22 18:35:22,992 : INFO : EPOCH 4 - PROGRESS: at 45.07% examples, 200875 words/s, in_qsize 7, out_qsize 0
# 2021-11-22 18:35:23,998 : INFO : EPOCH 4 - PROGRESS: at 93.74% examples, 207680 words/s, in_qsize 3, out_qsize 2
# 2021-11-22 18:35:24,006 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-11-22 18:35:24,012 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-11-22 18:35:24,030 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-11-22 18:35:24,050 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-11-22 18:35:24,051 : INFO : EPOCH - 4 : training on 616684 raw words (444758 effective words) took 2.1s, 215531 effective words/s
# 2021-11-22 18:35:25,071 : INFO : EPOCH 5 - PROGRESS: at 43.49% examples, 193387 words/s, in_qsize 7, out_qsize 0
# 2021-11-22 18:35:26,099 : INFO : EPOCH 5 - PROGRESS: at 93.86% examples, 205150 words/s, in_qsize 3, out_qsize 2
# 2021-11-22 18:35:26,107 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-11-22 18:35:26,119 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-11-22 18:35:26,139 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-11-22 18:35:26,150 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-11-22 18:35:26,153 : INFO : EPOCH - 5 : training on 616684 raw words (444666 effective words) took 2.1s, 212937 effective words/s
# 2021-11-22 18:35:27,192 : INFO : EPOCH 6 - PROGRESS: at 45.04% examples, 196430 words/s, in_qsize 7, out_qsize 0
# 2021-11-22 18:35:28,183 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-11-22 18:35:28,187 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-11-22 18:35:28,200 : INFO : EPOCH 6 - PROGRESS: at 98.67% examples, 215941 words/s, in_qsize 1, out_qsize 1
# 2021-11-22 18:35:28,202 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-11-22 18:35:28,222 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-11-22 18:35:28,224 : INFO : EPOCH - 6 : training on 616684 raw words (445272 effective words) took 2.1s, 216172 effective words/s
# 2021-11-22 18:35:29,275 : INFO : EPOCH 7 - PROGRESS: at 45.07% examples, 194207 words/s, in_qsize 6, out_qsize 1
# 2021-11-22 18:35:30,275 : INFO : EPOCH 7 - PROGRESS: at 93.86% examples, 204931 words/s, in_qsize 4, out_qsize 0
# 2021-11-22 18:35:30,292 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-11-22 18:35:30,323 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-11-22 18:35:30,348 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-11-22 18:35:30,357 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-11-22 18:35:30,360 : INFO : EPOCH - 7 : training on 616684 raw words (445117 effective words) took 2.1s, 209558 effective words/s
# 2021-11-22 18:35:31,426 : INFO : EPOCH 8 - PROGRESS: at 45.07% examples, 191211 words/s, in_qsize 5, out_qsize 2
# 2021-11-22 18:35:32,381 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-11-22 18:35:32,410 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-11-22 18:35:32,441 : INFO : EPOCH 8 - PROGRESS: at 98.31% examples, 211452 words/s, in_qsize 1, out_qsize 1
# 2021-11-22 18:35:32,444 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-11-22 18:35:32,447 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-11-22 18:35:32,449 : INFO : EPOCH - 8 : training on 616684 raw words (444777 effective words) took 2.1s, 214076 effective words/s
# 2021-11-22 18:35:33,487 : INFO : EPOCH 9 - PROGRESS: at 45.25% examples, 197428 words/s, in_qsize 7, out_qsize 0
# 2021-11-22 18:35:34,470 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-11-22 18:35:34,520 : INFO : EPOCH 9 - PROGRESS: at 96.70% examples, 209514 words/s, in_qsize 2, out_qsize 1
# 2021-11-22 18:35:34,524 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-11-22 18:35:34,548 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-11-22 18:35:34,552 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-11-22 18:35:34,553 : INFO : EPOCH - 9 : training on 616684 raw words (445346 effective words) took 2.1s, 213083 effective words/s
# 2021-11-22 18:35:35,637 : INFO : EPOCH 10 - PROGRESS: at 45.21% examples, 188544 words/s, in_qsize 7, out_qsize 0
# 2021-11-22 18:35:36,638 : INFO : EPOCH 10 - PROGRESS: at 95.37% examples, 205299 words/s, in_qsize 3, out_qsize 1
# 2021-11-22 18:35:36,641 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-11-22 18:35:36,643 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-11-22 18:35:36,656 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-11-22 18:35:36,677 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-11-22 18:35:36,678 : INFO : EPOCH - 10 : training on 616684 raw words (445136 effective words) took 2.1s, 210797 effective words/s
# 2021-11-22 18:35:36,680 : INFO : training on a 6166840 raw words (4450666 effective words) took 21.0s, 211981 effective words/s
# CPU times: user 43.5 s, sys: 514 ms, total: 44.1 s
# Wall time: 24.7 s

# %% [markdown]
# ## Averaged Document Vectors
#
# A sentence in very simple terms is a collection of words. By now we know how to transform words into vector representation. But how do we transform sentences and documents into vector representation?
#
# A simple and naïve way is to average all words in a given sentence to form a sentence vector. In this section, we will leverage this technique itself to prepare our sentence/document vectors

# %% [markdown]
# ### **Question 4**: **Complete** the following utility to build a function to generate and obtain averaged document embeddings (3 points)

# %%
def averaged_doc_vectorizer(corpus, model, num_features):
    vocabulary = set(model.wv.index2word)
    
    def average_word_vectors(words, model, vocabulary, num_features):
        feature_vector = np.zeros((num_features,), dtype="float64")
        nwords = 0.
        
        for word in tqdm(words):
            if word in vocabulary: 
                nwords = nwords + 1.
                feature_vector = np.add(feature_vector, model.wv[word])
        if nwords:
            feature_vector = np.divide(feature_vector, nwords)

        return feature_vector

    features = [average_word_vectors(tokenized_sentence, model, vocabulary, num_features)
                    for tokenized_sentence in tqdm(corpus)]
    return np.array(features)

# %%
# generate averaged word vector features from word2vec model
avg_w2v_train_features = averaged_doc_vectorizer(corpus=tokenized_train, model=w2v_model,
                                                     num_features=w2v_num_features)
avg_w2v_test_features = averaged_doc_vectorizer(corpus=tokenized_test, model=w2v_model,
                                                    num_features=w2v_num_features)
# Out:
# Streaming output truncated to the last 5000 lines.
#
# 100%|██████████| 11/11 [00:00<00:00, 44880.68it/s]
#  69%|██████▉   | 5627/8125 [01:39<00:46, 53.34it/s]
# 100%|██████████| 9/9 [00:00<00:00, 32208.82it/s]
#
# 100%|██████████| 8/8 [00:00<00:00, 38926.26it/s]
#
# 100%|██████████| 9/9 [00:00<00:00, 41573.50it/s]
#
# 100%|██████████| 13/13 [00:00<00:00, 57035.51it/s]
#
# 100%|██████████| 50/50 [00:00<00:00, 115418.38it/s]
#
# 100%|██████████| 8/8 [00:00<00:00, 42690.12it/s]
#
# 100%|██████████| 14/14 [00:00<00:00, 45661.16it/s]
#  69%|██████▉   | 5634/8125 [01:40<00:43, 57.48it/s]
# 100%|██████████| 15/15 [00:00<00:00, 62851.71it/s]
#
# 100%|██████████| 12/12 [00:00<00:00, 37117.73it/s]
#
# 100%|██████████| 4/4 [00:00<00:00, 20610.83it/s]
#
# 100%|██████████| 8/8 [00:00<00:00, 35432.35it/s]
#
# 100%|██████████| 59/59 [00:00<00:00, 69375.93it/s]
#
# 100%|██████████| 31/31 [00:00<00:00, 52598.47it/s]
#
# 100%|██████████| 45/45 [00:00<00:00, 71224.03it/s]
#  69%|██████▉   | 5641/8125 [01:40<00:43, 57.62it/s]
# 100%|██████████| 11/11 [00:00<00:00, 46887.54it/s]
#
# 100%|██████████| 6/6 [00:00<00:00, 28435.96it/s]
#
# 100%|██████████| 78/78 [00:00<00:00, 97223.09it/s]
#
# 100%|██████████| 8/8 [00:00<00:00, 33156.55it/s]
#
# 100%|██████████| 10/10 [00:00<00:00, 38339.16it/s]
#
# 100%|██████████| 3/3 [00:00<00:00, 20798.20it/s]
#
# 100%|██████████| 14/14 [00:00<00:00, 56030.78it/s]
#  70%|██████▉   | 5648/8125 [01:40<00:42, 58.06it/s]
# 100%|██████████| 20/20 [00:00<00:00, 57260.12it/s]
#
# 100%|██████████| 4/4 [00:00<00:00, 20893.17it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 16008.79it/s]
#
# 100%|██████████| 8/8 [00:00<00:00, 30476.32it/s]
#
# 100%|██████████| 2/2 [00:00<00:00, 11798.32it/s]
#
# 100%|██████████| 50/50 [00:00<00:00, 98365.48it/s]
#
# 100%|██████████| 26/26 [00:00<00:00, 66132.14it/s]
#  70%|██████▉   | 5655/8125 [01:40<00:40, 60.68it/s]
# 100%|██████████| 11/11 [00:00<00:00, 33120.85it/s]
#
# 100%|██████████| 21/21 [00:00<00:00, 63687.91it/s]
#
# 100%|██████████| 10/10 [00:00<00:00, 44384.17it/s]
#
# 100%|██████████| 12/12 [00:00<00:00, 43129.09it/s]
#
# 100%|██████████| 87/87 [00:00<00:00, 111183.56it/s]
#
# 100%|██████████| 77/77 [00:00<00:00, 110641.11it/s]
#
# 100%|██████████| 9/9 [00:00<00:00, 38876.14it/s]
#  70%|██████▉   | 5662/8125 [01:40<00:41, 59.98it/s]
# 100%|██████████| 13/13 [00:00<00:00, 53773.13it/s]
#
# 100%|██████████| 5/5 [00:00<00:00, 18825.42it/s]
#
# 100%|██████████| 4/4 [00:00<00:00, 25458.60it/s]
#
# 100%|██████████| 13/13 [00:00<00:00, 50161.87it/s]
#
# 100%|██████████| 6/6 [00:00<00:00, 35696.20it/s]
#
# 100%|██████████| 5/5 [00:00<00:00, 26990.37it/s]
#
# 100%|██████████| 20/20 [00:00<00:00, 51590.46it/s]
#  70%|██████▉   | 5669/8125 [01:40<00:48, 50.37it/s]
# 100%|██████████| 16/16 [00:00<00:00, 34397.16it/s]
#
# 100%|██████████| 45/45 [00:00<00:00, 103534.66it/s]
#
# 100%|██████████| 25/25 [00:00<00:00, 76818.75it/s]
#
# 100%|██████████| 41/41 [00:00<00:00, 93358.56it/s]
#
# 100%|██████████| 6/6 [00:00<00:00, 39444.87it/s]
#
# 100%|██████████| 17/17 [00:00<00:00,
/s]
#
# 100%|██████████| 7/7 [00:00<00:00, 44961.91it/s]
#
# 100%|██████████| 62/62 [00:00<00:00, 91759.65it/s]
#
# 100%|██████████| 46/46 [00:00<00:00, 115670.25it/s]
#
# 100%|██████████| 12/12 [00:00<00:00, 60494.77it/s]
#
# 100%|██████████| 12/12 [00:00<00:00, 62601.55it/s]
#
# 100%|██████████| 11/11 [00:00<00:00, 59150.44it/s]
# 100%|█████████▉| 8086/8125 [02:21<00:00, 63.11it/s]
# 100%|██████████| 8/8 [00:00<00:00, 35887.09it/s]
#
# 100%|██████████| 8/8 [00:00<00:00, 41995.53it/s]
#
# 100%|██████████| 8/8 [00:00<00:00, 42799.02it/s]
#
# 100%|██████████| 11/11 [00:00<00:00, 53399.70it/s]
#
# 100%|██████████| 74/74 [00:00<00:00, 123607.53it/s]
#
# 100%|██████████| 5/5 [00:00<00:00, 30526.23it/s]
#
# 100%|██████████| 7/7 [00:00<00:00, 34952.53it/s]
#
# 100%|██████████| 11/11 [00:00<00:00, 65443.04it/s]
# 100%|█████████▉| 8094/8125 [02:21<00:00, 66.31it/s]
# 100%|██████████| 13/13 [00:00<00:00, 57638.43it/s]
#
# 100%|██████████| 32/32 [00:00<00:00, 64219.01it/s]
#
# 100%|██████████| 14/14 [00:00<00:00, 61745.80it/s]
#
# 100%|██████████| 38/38 [00:00<00:00, 89440.83it/s]
#
# 100%|██████████| 10/10 [00:00<00:00, 53159.75it/s]
#
# 100%|██████████| 13/13 [00:00<00:00, 66252.68it/s]
#
# 100%|██████████| 14/14 [00:00<00:00, 69573.76it/s]
#
# 100%|██████████| 27/27 [00:00<00:00, 78917.22it/s]
# 100%|█████████▉| 8102/8125 [02:21<00:00, 66.33it/s]
# 100%|██████████| 51/51 [00:00<00:00, 77757.00it/s]
#
# 100%|██████████| 16/16 [00:00<00:00, 59493.67it/s]
#
# 100%|██████████| 15/15 [00:00<00:00, 40880.16it/s]
#
# 100%|██████████| 9/9 [00:00<00:00, 35511.51it/s]
#
# 100%|██████████| 24/24 [00:00<00:00, 80466.26it/s]
#
# 100%|██████████| 12/12 [00:00<00:00, 61230.72it/s]
#
# 100%|██████████| 5/5 [00:00<00:00, 25763.54it/s]
# 100%|█████████▉| 8109/8125 [02:22<00:00, 62.71it/s]
# 100%|██████████| 11/11 [00:00<00:00, 53092.46it/s]
#
# 100%|██████████| 15/15 [00:00<00:00, 60262.99it/s]
#
# 100%|██████████| 42/42 [00:00<00:00, 80328.67it/s]
#
# 100%|██████████| 8/8 [00:00<00:00, 10318.09it/s]
#
# 100%|██████████| 48/48 [00:00<00:00, 66291.27it/s]
#
# 100%|██████████| 6/6 [00:00<00:00, 28695.35it/s]
#
# 100%|██████████| 8/8 [00:00<00:00, 41786.34it/s]
# 100%|█████████▉| 8116/8125 [02:22<00:00, 51.92it/s]
# 100%|██████████| 9/9 [00:00<00:00, 38996.63it/s]
#
# 100%|██████████| 11/11 [00:00<00:00, 52548.23it/s]
#
# 100%|██████████| 14/14 [00:00<00:00, 49386.25it/s]
#
# 100%|██████████| 9/9 [00:00<00:00, 41255.45it/s]
#
# 100%|██████████| 11/11 [00:00<00:00, 56959.68it/s]
#
# 100%|██████████| 47/47 [00:00<00:00, 80858.20it/s]
# 100%|█████████▉| 8122/8125 [02:22<00:00, 44.93it/s]
# 100%|██████████| 3/3 [00:00<00:00, 19358.33it/s]
#
# 100%|██████████| 120/120 [00:00<00:00, 113924.06it/s]
#
# 100%|██████████| 11/11 [00:00<00:00, 53585.77it/s]
# 100%|██████████| 8125/8125 [02:22<00:00, 57.00it/s]

# %%
print('Word2Vec model:> Train features shape:', avg_w2v_train_features.shape, 
      ' Test features shape:', avg_w2v_test_features.shape)
# Out:
# Word2Vec model:> Train features shape: (32498, 300)  Test features shape: (8125, 300)

# %% [markdown]
# ## Define DNN Model
#
# Let us leverage ``tensorflow.keras`` to build our deep neural network for movie review classification task.
# We will make use of ``Dense`` layers with ``ReLU`` activation and ``Dropout`` to prevent overfitting.

# %% [markdown]
# ### **Question 5**: **Complete** the following utility to build a deep neural network for classification task (3 points)
#
# Use a similar architecture as the tutorial, key components listed below for reference:
#
# - 3 Dense Layers
# - 512 - 256 - 256 (neurons)
# - 20% dropout in each layer
# - 1 output layer for binary classification
# - binary crossentropy loss
# - adam optimizer

# %%
def construct_deepnn_architecture(num_input_features):
    dnn_model = Sequential()
    dnn_model.add(Dense(512, input_shape=(num_input_features,)))
    dnn_model.add(Activation('relu'))
    dnn_model.add(Dropout(0.2))
    
    dnn_model.add(Dense(256))
    dnn_model.add(Activation('relu'))
    dnn_model.add(Dropout(0.2))
    
    dnn_model.add(Dense(256))
    dnn_model.add(Activation('relu'))
    dnn_model.add(Dropout(0.2))
    
    dnn_model.add(Dense(1))
    dnn_model.add(Activation('sigmoid'))

    dnn_model.compile(loss='binary_crossentropy', optimizer='adam',                 
                      metrics=['accuracy'])
    return dnn_model

# %% [markdown]
# ## Compile and Visualize Model

# %%
w2v_dnn = construct_deepnn_architecture(num_input_features=w2v_num_features)

# %%
w2v_dnn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 512)               154112
#
#  activation (Activation)     (None, 512)               0
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  activation_1 (Activation)   (None, 256)               0
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 256)               65792
#
#  activation_2 (Activation)   (None, 256)               0
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense_3 (Dense)             (None, 1)                 257
#
#  activation_3 (Activation)   (None, 1)                 0
#
# =================================================================
# Total params: 351,489
# Trainable params: 351,489
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Train the Model using Word2Vec Features
#
# The first exercise is to leverage word2vec features as input to our deep neural network to perform moview review classification

# %% [markdown]
# ### **Question 6**: **Train** the model (1 point)

# %%
batch_size = 64
w2v_dnn.fit(avg_w2v_train_features, y_train, epochs=10, batch_size=batch_size, 
            shuffle=True, validation_split=0.1, verbose=1)
# Out:
# Epoch 1/10
# 457/457 [==============================] - 5s 4ms/step - loss: 0.6428 - accuracy: 0.6112 - val_loss: 0.6350 - val_accuracy: 0.6142
# Epoch 2/10
# 457/457 [==============================] - 2s 4ms/step - loss: 0.6188 - accuracy: 0.6329 - val_loss: 0.6261 - val_accuracy: 0.6166
# Epoch 3/10
# 457/457 [==============================] - 2s 4ms/step - loss: 0.6014 - accuracy: 0.6503 - val_loss: 0.6004 - val_accuracy: 0.6538
# Epoch 4/10
# 457/457 [==============================] - 2s 4ms/step - loss: 0.5897 - accuracy: 0.6624 - val_loss: 0.5914 - val_accuracy: 0.6560
# Epoch 5/10
# 457/457 [==============================] - 2s 4ms/step - loss: 0.5798 - accuracy: 0.6714 - val_loss: 0.5816 - val_accuracy: 0.6760
# Epoch 6/10
# 457/457 [==============================] - 2s 4ms/step - loss: 0.5662 - accuracy: 0.6842 - val_loss: 0.5813 - val_accuracy: 0.6732
# Epoch 7/10
# 457/457 [==============================] - 2s 4ms/step - loss: 0.5586 - accuracy: 0.6908 - val_loss: 0.5750 - val_accuracy: 0.6705
# Epoch 8/10
# 457/457 [==============================] - 2s 4ms/step - loss: 0.5483 - accuracy: 0.6948 - val_loss: 0.5724 - val_accuracy: 0.6791
# Epoch 9/10
# 457/457 [==============================] - 2s 4ms/step - loss: 0.5408 - accuracy: 0.7026 - val_loss: 0.5664 - val_accuracy: 0.6806
# Epoch 10/10
# 457/457 [==============================] - 2s 4ms/step - loss: 0.5315 - accuracy: 0.7097 - val_loss: 0.5653 - val_accuracy: 0.6852

# %% [markdown]
# ### Evaluate Model

# %%
from sklearn.metrics import confusion_matrix, classification_report

# %%
y_pred = w2v_dnn.predict(avg_w2v_test_features).ravel()
predictions = le.inverse_transform(y_pred)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-3ca39acd39d2> in <module>()
#       1 y_pred = w2v_dnn.predict(avg_w2v_test_features).ravel()
# ----> 2 predictions = le.inverse_transform(y_pred)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_label.py in inverse_transform(self, y)
#     159         diff = np.setdiff1d(y, np.arange(len(self.classes_)))
#     160         if len(diff):
# --> 161             raise ValueError("y contains previously unseen labels: %s" % str(diff))
#     162         y = np.asarray(y)
#     163         return self.classes_[y]
#
# ValueError: y contains previously unseen labels: [3.6911132e-07 5.8385481e-06 2.5921487e-05 ... 9.9990499e-01 9.9990821e-01
#  9.9993587e-01]

# %% [markdown]
# ### **Question 7**: **Get** evaluation results (1 point)

# %%
labels = le.classes_.tolist()
# print classification report
print(classification_report(test_sentiments, predictions))
# display confusion matrix
pd.DataFrame(confusion_matrix(test_sentiments, predictions), index=labels, columns=labels)

# %% [markdown]
# Congratulations you have built your first hate speech detection model!
#
# We will look at more complex models in the future to see if we can improve this performance given this is a pretty complex dataset \ domain as compared to basic sentiment analysis
